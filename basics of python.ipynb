# %% [markdown]
# ####HELLO WORLD

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Python is case sensitive

# %%
Print("hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e94fdc0344b> in <cell line: 1>()
# ----> 1 Print("hello world")
#
# NameError: name 'Print' is not defined

# %%
print(100)
# Out:
# 100

# %% [markdown]
# String should always inside quotation
# (single or double both would be fine)

# %%
print("Hardik")
# Out:
# Hardik

# %% [markdown]
# Data Types

# %% [markdown]
# Int

# %%
X=100
X
# Out:
# 100

# %%
print(X)
# Out:
# 100

# %% [markdown]
# Float

# %%
print(10.7)
# Out:
# 10.7

# %%
type(X)
# Out:
# int

# %%
X=10.5
type(X)
# Out:
# float

# %%
y="Hardik"
type(y)
# Out:
# str

# %% [markdown]
# Boolean

# %%
z=False
type(z)
# Out:
# bool

# %%
x=10
type(x)
x
# Out:
# 10

# %%
x,type(x)
# Out:
# (10, int)

# %%
x,y=10,2
x
y
# Out:
# 2

# %%
x,y
# Out:
# (10, 2)

# %% [markdown]
# *  Print your name
# * Data type of your name
# *  Print your age
# *  Data type

# %%
Name = "Hardik"
Age = "20"
Name , Age , type(Name) , type(Age)
# Out:
# ('Hardik', '20', str, str)

# %% [markdown]
# Rules for naming variables

# %% [markdown]
# 1. variable name should not start with a number.
# 2. no special character is allowed in between except underscore.
# 3. space is not allowed.
# 4. variable name should start with underscore or albhabet.

# %%
book_name=("pyton","AI","DS")
book_name
# Out:
# ('pyton', 'AI', 'DS')

# %%
book+name=("pyton","AI","DS")
book+name
# Out:
#   File "<ipython-input-24-5c8441e505b0>", line 1
#     book+name=("pyton","AI","DS")
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
29book_name=("python")
29book_name
# Out:
#   File "<ipython-input-26-0233f04fa182>", line 1
#     29book_name=("python")
#      ^
# SyntaxError: invalid decimal literal

# %%
_bookname=("python")
_bookname
# Out:
# 'python'
